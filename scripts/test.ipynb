# %%
initial_state = {
    "ticker": "2330",
    "company_name": "台積電",
    "sector_name": "半導體業",

    "technical_data": {
        # 放你之前 Technical Snapshot 的 15 個 features
    },

    "chip_data": {
        # 放你剛才 Chip Snapshot 的 15 個 features
    },

    "macro_data": {
        # 放你之前測成功的 Macro data
    },

    "sector_context": {
        "sector": "Semiconductor",
        "relative_strength": "Neutral",
        "sector_trend": "Weak",
    },
}

result = graph.invoke(initial_state)

print("\n=== Final Result ===")

print("Technical:", result["technical_report"])
print("Chip:", result["chip_report"])
print("Macro:", result["macro_report"])
print("Sector:", result["sector_report"])
print("PM:", result["pm_report"])
# Out:
# [Sector Node] Running...
# [Sector Node] Completed: score=30
#
# === Sector Node Result ===
# Score : 30
# ...
